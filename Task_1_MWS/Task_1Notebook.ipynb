# %% [markdown]
# # Marginal Working Group
# This is a program that will analyze the margin for JPL IPE MWG.

# %% [markdown]
# Import file from the directory you are working in.
# I will be using pandas to organize the .csv file that we are dealing with. df = Data Frame

# %%
import pandas as pd
import urllib
import os, sys, json, re
from math import *
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np


filename = "submasterDurations_sols2170to2395_postUpdate.json"
f = open(filename, "r")
df_kb = pd.read_json(f)


with open(filename) as fp:
    data = json.load(fp)

# %%
df_kb.dropna(axis = 0, how = "any", inplace = True)
df_kb.reset_index(drop = True, inplace = True)
df_kb
# Out:
#            sol2170_sub_00170  sol2170_sub_01170     sol2171_sub_00171  \
# 0                    19700.8            4.23859               6902.76
# 1                    277.157            116.761               1074.44
# 2  [arm, unidentified, ECAM]     [unidentified]  [otherSci, ECAM, SB]
# 3                       2170               2170                  2171
# 4                      17998                 91                7377.2
# 5                       1980                 30                   600
# 6                      19978                121                7977.2
# 7                  sub_00170          sub_01170             sub_00171
# 8          sol2170_sub_00170  sol2170_sub_01170     sol2171_sub_00171
#
#    sol2209_sub_00209  sol2209_sub_01209  sol2209_sub_02209  sol2209_sub_03209  \
# 0            245.929            66.3727            80.3913            66.4014
# 1            294.071            233.627            219.609            233.599
# 2     [unidentified]     [unidentified]     [unidentified]     [unidentified]
# 3               2209               2209               2209               2209
# 4                420                180                180                180
# 5                120                120                120                120
# 6                540                300                300                300
# 7          sub_00209          sub_01209          sub_02209          sub_03209
# 8  sol2209_sub_00209  sol2209_sub_01209  sol2209_sub_02209  sol2209_sub_03209
#
#    sol2209_sub_04209  sol2209_sub_04210  sol2209_sub_05209  ...  \
# 0            59.3074            110.021            59.4164  ...
# 1            240.693            189.979            240.584  ...
# 2     [unidentified]     [unidentified]     [unidentified]  ...
# 3               2209               2209               2209  ...
# 4                180                180                180  ...
# 5                120                120                120  ...
# 6                300                300                300  ...
# 7          sub_04209          sub_04210          sub_05209  ...
# 8  sol2209_sub_04209  sol2209_sub_04210  sol2209_sub_05209  ...
#
#       sol2389_sub_00389  sol2389_sub_01389  sol2390_sub_00390  \
# 0               5696.73            2217.48            5307.17
# 1               620.036            1082.52             1503.9
# 2  [otherSci, ECAM, SB]               [SB]         [SB, ECAM]
# 3                  2389               2389               2390
# 4               5716.77               3000            6301.07
# 5                   600                300                510
# 6               6316.77               3300            6811.07
# 7             sub_00389          sub_01389          sub_00390
# 8     sol2389_sub_00389  sol2389_sub_01389  sol2390_sub_00390
#
#    sol2390_sub_01390     sol2391_sub_00391  sol2391_sub_01391  \
# 0            1207.38               5143.63            831.644
# 1            205.327               1003.52            284.356
# 2               [SB]  [otherSci, ECAM, SB]               [SB]
# 3               2390                  2391               2391
# 4            1262.71               5697.15                966
# 5                150                   450                150
# 6            1412.71               6147.15               1116
# 7          sub_01390             sub_00391          sub_01391
# 8  sol2390_sub_01390     sol2391_sub_00391  sol2391_sub_01391
#
#    sol2392_sub_00392          sol2393_sub_00393  sol2393_sub_01393  \
# 0                559                    2204.44            1742.88
# 1                 91                    846.558            537.124
# 2   [otherSci, ECAM]  [unidentified, arm, ECAM]               [SB]
# 3               2392                       2393               2393
# 4                620                       2421               2040
# 5                 30                        630                240
# 6                650                       3051               2280
# 7          sub_00392                  sub_00393          sub_01393
# 8  sol2392_sub_00392          sol2393_sub_00393  sol2393_sub_01393
#
#       sol2394_sub_00394
# 0               4940.31
# 1               317.506
# 2  [otherSci, ECAM, SB]
# 3                  2394
# 4               4957.82
# 5                   300
# 6               5257.82
# 7             sub_00394
# 8     sol2394_sub_00394
#
# [9 rows x 383 columns]

# %%
#Making sure right file type

# %%
# df_kb = df_kb.drop(columns=['recordType', 'sessionHost', 'sessionId','fromSse', 'eventId', 'realtime', 'sclk', 'scet',
#                     'ert', 'rct', 'metadataKeywordList','metadataValuesList',
#                     'sessionDssId','stringId'])

# df_kb

# %%
#Write out
# df_kb.to_csv(r'output.csv')

# %%
# length = len(df_kb)
# for i in range(0, length):
#     print(df_kb.iloc[i])


planSubDurArr = []
actSubDurArr = []
amountMarginUsedArr = {"all":[], "sb":[],"arm": [],"drive": []}
percentMarginUsedArr = {"all":[], "sb":[],"arm": [],"drive": []}
percentPlannedMarginArr = {"all":[], "sb":[],"arm": [],"drive": []}
amountUnusedTimeArr = {"all":[], "sb":[],"arm": [],"drive": []}
subsUsingMarginArr = []
over50PerMarginUseSBArr = []

# %%
for uniqueId in data.keys():
    amountMarginUsed = round((data[uniqueId]['planMarginDur'] - data[uniqueId]['actMarginDur'])/60,3)
    print(uniqueId, amountMarginUsed)
# Out:
# sol2170_sub_00170 28.381
# sol2170_sub_01170 -1.446
# sol2171_sub_00171 -7.907
# sol2209_sub_00209 -2.901
# sol2209_sub_01209 -1.894
# sol2209_sub_02209 -1.66
# sol2209_sub_03209 -1.893
# sol2209_sub_04209 -2.012
# sol2209_sub_04210 -1.166
# sol2209_sub_05209 -2.01
# sol2209_sub_05210 -1.636
# sol2209_sub_06209 -1.33
# sol2209_sub_06210 -1.649
# sol2209_sub_07209 -1.426
# sol2209_sub_07210 -1.653
# sol2209_sub_08209 -1.772
# sol2209_sub_09209 -1.198
# sol2209_sub_10209 -1.176
# sol2209_sub_11209 -1.118
# sol2209_sub_12209 -0.931
# sol2209_sub_13209 -0.781
# sol2209_sub_14209 -0.792
# sol2209_sub_15209 -0.785
# sol2209_sub_16209 -1.304
# sol2210_sub_00210 -1.274
# sol2210_sub_01210 -3.831
# sol2210_sub_02210 0.006
# sol2211_sub_00211 -0.53
# sol2211_sub_01211 -1.012
# sol2211_sub_02211 -1.5
# sol2212_sub_00212 -0.706
# sol2212_sub_01212 -1.47
# sol2213_sub_00213 -1.398
# sol2213_sub_01213 0.083
# sol2213_sub_02213 -7.554
# sol2213_sub_03213 -3.187
# sol2214_sub_00214 -8.192
# sol2215_sub_00215 -2.97
# sol2358_sub_00358 -8.84
# sol2358_sub_01358 -3.486
# sol2359_sub_00359 -1.535
# sol2359_sub_01359 -3.368
# sol2359_sub_02359 -5.913
# sol2359_sub_03359 -0.607
# sol2359_sub_04359 -0.55
# sol2360_sub_00360 -11.715
# sol2361_sub_00361 -5.455
# sol2361_sub_01361 -12.054
# sol2361_sub_02361 -13.895
# sol2361_sub_03361 -4.004
# sol2361_sub_04361 -0.579
# sol2362_sub_00362 -1.014
# sol2362_sub_01362 -11.258
# sol2363_sub_00363 -6.086
# sol2363_sub_01363 -12.908
# sol2363_sub_02363 -0.439
# sol2363_sub_03363 -3.082
# sol2364_sub_00364 0.725
# sol2364_sub_01364 -29.257
# sol2364_sub_02364 -0.536
# sol2365_sub_00365 -2.575
# sol2365_sub_01365 -4.391
# sol2365_sub_02365 -7.977
# sol2365_sub_03365 -3.483
# sol2365_sub_04365 -2.58
# sol2365_sub_05365 -9.221
# sol2366_sub_00366 -0.195
# sol2367_sub_00367 -2.959
# sol2367_sub_01367 -2.572
# sol2367_sub_02367 -1.104
# sol2368_sub_00368 0.854
# sol2368_sub_01368 -38.39
# sol2368_sub_02368 -1.422
# sol2369_sub_00369 -0.346
# sol2369_sub_01369 -2.737
# sol2370_sub_00370 -89.581
# sol2370_sub_01370 -0.345
# sol2371_sub_00371 -8.881
# sol2371_sub_01371 -0.203
# sol2372_sub_00372 -2.212
# sol2372_sub_01372 -13.832
# sol2373_sub_00373 -0.277
# sol2373_sub_01373 -1.569
# sol2374_sub_00374 -6.518
# sol2374_sub_01374 -1.835
# sol2374_sub_02374 -8.069
# sol2375_sub_00375 -6.563
# sol2375_sub_01375 -6.832
# sol2375_sub_03375 -3.606
# sol2375_sub_04375 -26.304
# sol2376_sub_00376 -8.077
# sol2376_sub_01376 -1.226
# sol2376_sub_02376 -8.837
# sol2377_sub_00377 -0.864
# sol2377_sub_01377 -8.952
# sol2377_sub_02377 -1.85
# sol2378_sub_00378 -5.168
# sol2379_sub_00379 -3.956
# sol2380_sub_00380 -4.921
# sol2380_sub_01380 -1.58
# sol2381_sub_00381 -1.289
# sol2381_sub_01381 -9.247
# sol2381_sub_02381 -0.205
# sol2382_sub_00382 -4.457
# sol2382_sub_01382 -12.359
# sol2382_sub_02382 -4.185
# sol2384_sub_00384 -90.91
# sol2385_sub_01385 -2.318
# sol2386_sub_00386 -8.629
# sol2386_sub_01386 -0.865
# sol2386_sub_02386 -4.558
# sol2387_sub_00387 -4.62
# sol2388_sub_00388 -3.347
# sol2388_sub_01388 -20.409
# sol2389_sub_00389 -0.334
# sol2389_sub_01389 -13.042
# sol2390_sub_00390 -16.565
# sol2390_sub_01390 -0.922
# sol2391_sub_00391 -9.225
# sol2391_sub_01391 -2.239
# sol2392_sub_00392 -1.017
# sol2393_sub_00393 -3.609
# sol2393_sub_01393 -4.952
# sol2394_sub_00394 -0.292
