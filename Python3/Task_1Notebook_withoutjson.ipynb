# %% [markdown]
# # Marginal Working Group
# This is a program that will analyze the margin for JPL IPE MWG.

# %% [markdown]
# Import file from the directory you are working in.
# I will be using pandas to organize the .csv file that we are dealing with. df = Data Frame

# %%
import pandas as pd
import urllib
import os, sys, json, re
from math import *
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np


filename = "sol2170.csv"
f = open(filename, "r")
df_kb = pd.read_csv(f)


# with open(filename) as fp:
#     data = json.load(fp)

# %%
# Standard plotly imports
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_kb.dropna(axis = 0, how = "any", inplace = True)
df_kb.reset_index(drop = True, inplace = True)
df_kb
# Out:
#       recordType  sessionId   sessionHost                                name  \
# 0            Evr      24945  mslsmsampcs1     FSM_EVR_FLIGHT_SOFTWARE_VERSION
# 1            Evr      24945  mslsmsampcs1                  MEM_EVR_BPMM_CRC32
# 2            Evr      24945  mslsmsampcs1              FSM_EVR_FSW_BUILD_TIME
# 3            Evr      24945  mslsmsampcs1            FSM_EVR_FSW_ELAPSED_TIME
# 4            Evr      24967  mslsmsampcs1               AUT_EVR_BUFFERS_AVAIL
# 5            Evr      24967  mslsmsampcs1            AUT_EVR_AUT_MEMORY_CHECK
# 6            Evr      24967  mslsmsampcs1        AUT_EVR_BUFFERS_AS_REQUESTED
# 7            Evr      24967  mslsmsampcs1                  AUT_EVR_INIT_TYPE3
# 8            Evr      24967  mslsmsampcs1                   AUT_EVR_INIT_DONE
# 9            Evr      24967  mslsmsampcs1             CRCMGR_EVR_CRCC_PRESENT
# 10           Evr      24967  mslsmsampcs1         NVMCAMMGR_EVR_CRC_5_NOT_SET
# 11           Evr      24967  mslsmsampcs1  NVMCAMMGR_EVR_NVMCAM_CARD_DETECTED
# 12           Evr      24967  mslsmsampcs1     NVMCAMMGR_EVR_NOR_PWRON_ALREADY
# 13           Evr      24967  mslsmsampcs1     NVMCAMMGR_EVR_NVMRAM_START_INIT
# 14           Evr      24967  mslsmsampcs1  NVMCAMMGR_EVR_SAVED_NVMRAM_REQUEST
# 15           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 16           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 17           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 18           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 19           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# 20           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 21           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# 22           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# 23           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 24           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# 25           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 26           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 27           Evr      24967  mslsmsampcs1         OSAL_EVR_OS_TASK_REGISTERED
# 28           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# 29           Evr      24967  mslsmsampcs1          OSAL_EVR_NO_OS_TASK_EXISTS
# ...          ...        ...           ...                                 ...
# 55719        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55720        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55721        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55722        Evr      24967  mslsmsampcs1             SDST_EVR_STATE_ASSERTED
# 55723        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55724        Evr      24967  mslsmsampcs1           SDST_EVR_SENDING_CBIT_CMD
# 55725        Evr      24967  mslsmsampcs1             CBM_EVR_XCONFIG_RECV_5B
# 55726        Evr      24967  mslsmsampcs1              CBM_EVR_XCONFIG_RECV_6
# 55727        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55728        Evr      24967  mslsmsampcs1              CBM_EVR_XCONFIG_RECV_7
# 55729        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55730        Evr      24967  mslsmsampcs1              CBM_EVR_XCONFIG_RECV_8
# 55731        Evr      24967  mslsmsampcs1             SDST_EVR_SENDING_CMD_ID
# 55732        Evr      24967  mslsmsampcs1           CBM_EVR_XCONFIG_RECV_DONE
# 55733        Evr      24967  mslsmsampcs1         CBM_EVR_BKGD_RESTART_EVR_DP
# 55734        Evr      24967  mslsmsampcs1                EVR_EVR_REC_DP_EMPTY
# 55735        Evr      24967  mslsmsampcs1                EVR_EVR_REC_DP_EMPTY
# 55736        Evr      24967  mslsmsampcs1                EVR_EVR_REC_DP_EMPTY
# 55737        Evr      24967  mslsmsampcs1     EVR_EVR_REC_STREAM_DP_COMPLETED
# 55738        Evr      24967  mslsmsampcs1     EVR_EVR_REC_STREAM_DP_COMPLETED
# 55739        Evr      24967  mslsmsampcs1     EVR_EVR_REC_STREAM_DP_COMPLETED
# 55740        Evr      24967  mslsmsampcs1     EVR_EVR_REC_STREAM_DP_COMPLETED
# 55741        Evr      24967  mslsmsampcs1            CBM_EVR_SENDING_DMS_STOP
# 55742        Evr      24954  mslsmsampcs1                   CBM_EVR_BKGD_DONE
# 55743        Evr      24954  mslsmsampcs1           CBM_EVR_NEXT_FIVE_WINDOWS
# 55744        Evr      24967  mslsmsampcs1                  CBM_EVR_WAIT_BEGIN
# 55745        Evr      24967  mslsmsampcs1       EVR_EVR_REC_STREAM_DP_CREATED
# 55746        Evr      24967  mslsmsampcs1       EVR_EVR_REC_STREAM_DP_CREATED
# 55747        Evr      24967  mslsmsampcs1       EVR_EVR_REC_STREAM_DP_CREATED
# 55748        Evr      24967  mslsmsampcs1       EVR_EVR_REC_STREAM_DP_CREATED
#
#           module        level     eventId  fromSse  realtime          sclk  \
# 0            fsm  ACTIVITY_HI   790726143    False     False  5.900926e+08
# 27     2018-258T10:19:37.314
# 28     2018-258T10:19:37.314
# 29     2018-258T10:19:37.314
# ...                      ...
# 55719  2018-258T10:20:06.295
# 55720  2018-258T10:20:06.295
# 55721  2018-258T10:20:06.295
# 55722  2018-258T10:20:06.295
# 55723  2018-258T10:20:06.296
# 55724  2018-258T10:20:06.296
# 55725  2018-258T10:20:06.296
# 55726  2018-258T10:20:06.296
# 55727  2018-258T10:20:06.296
# 55728  2018-258T10:20:06.296
# 55729  2018-258T10:20:06.296
# 55730  2018-258T10:20:06.296
# 55731  2018-258T10:20:06.296
# 55732  2018-258T10:20:06.296
# 55733  2018-258T10:20:06.469
# 55734  2018-258T10:20:06.469
# 55735  2018-258T10:20:06.469
# 55736  2018-258T10:20:06.469
# 55737  2018-258T10:20:06.469
# 55738  2018-258T10:20:06.469
# 55739  2018-258T10:20:06.470
# 55740  2018-258T10:20:06.470
# 55741  2018-258T10:20:06.470
# 55742  2018-257T14:05:43.431
# 55743  2018-257T14:05:43.433
# 55744  2018-258T10:20:06.470
# 55745  2018-258T10:20:06.470
# 55746  2018-258T10:20:06.470
# 55747  2018-258T10:20:06.470
# 55748  2018-258T10:20:06.470
#
#                                                  message  \
# 0      FSW version 0x0c7365fb, fsw_release_string=R12...
# 1      BPMM addr [0xbf898030], BPMM CRC-32 [0xc71c0011].
# 2      FSW build time: month 8 day 14 year 2014, hour...
# 3      Elapsed time since boot is 20 second(s), with ...
# 4      AUT got memory buffers: mem_rcvd 2097152, reco...
# 5      AUT memory has no data. recoverable FALSE, san...
# 6                         AUT got all requested buffers.
# 7                          AUT init type AUT_INIT_CLEAN.
# 8      AUT done with aut_init: ready for aut_finish_i...
# 9      CRCMGR CRCC Present, board type FLT, serial nu...
# 10       Saw CRC 5 was not set; doing normal NVMRAM init
# 11     Detected NVMCAM card with serial number 193; r...
# 12                   NOR power is already on; continuing
# 13           Starting NVMRAM initialization of section 2
# 14                 Received request for NVMCAM section 3
# 15     OS Task ipcom_syslogd with context id VXW_IPCO...
# 16     OS Task tExcTask with context id VXW_EXC_TASK_...
# 17     OS Task tJobTask with context id VXW_JOB_TASK_...
# 18     OS Task tLogTask with context id VXW_LOG_TASK_...
# 19     Task tNbioLog (VXW_NBIO_LOG_ENTRY) does not ex...
# 20     OS Task tWdbTask with context id VXW_WDB_TASK_...
# 21     Task tAioIoTask0 (VXW_AIO_0_TASK_ENTRY) does n...
# 22     Task tAioIoTask1 (VXW_AIO_1_TASK_ENTRY) does n...
# 23     OS Task tNet0 with context id VXW_NET_TASK_ENT...
# 24     Task tAioWait (VXW_AIO_WAIT_ENTRY) does not ex...
# 25     OS Task tPortmapd with context id VXW_PORTMAPD...
# 26     OS Task tRlogind with context id VXW_RLOGIND_E...
# 27     OS Task tShell0 with context id VXW_SHELL_ENTR...
# 28     Task SimTask (SIM_TASK_ENTRY) does not exist f...
# 29     Task SimIdleTask (SIM_IDLE_TASK_ENTRY) does no...
# ...                                                  ...
# 55719  Write to 1553 subaddress 29, num words = 1, bu...
# 55720  Write to 1553 subaddress 29, num words = 1, bu...
# 55721  Write to 1553 subaddress 29, num words = 1, bu...
# 55722              Default state asserted for SDST ROVER
# 55723  Write to 1553 subaddress 29, num words = 1, bu...
# 55724                 Sending CBIT command to SDST ROVER
# 55725  X-Band Config 5B: Not requesting reset for SDS...
# 55726  X-Band Recv Config 6: Setting SDST uplink rate...
# 55727  Write to 1553 subaddress 29, num words = 1, bu...
# 55728  X-Band Recv Config 7: Setting coherency of SDS...
# 55729  Write to 1553 subaddress 29, num words = 1, bu...
# 55730  X-Band Recv Config 8: Setting receiver bandwid...
# 55731  Write to 1553 subaddress 29, num words = 1, bu...
# 55732         X-Band Recv Config: Finished X-Band config
# 55733  Restarting recorded EVR production after estab...
# 55734  The recorded stream data product of category [...
# 55735  The recorded stream data product of category [...
# 55736  The recorded stream data product of category [...
# 55737  Closed EVR recorded stream data product: EVR c...
# 55738  Closed EVR recorded stream data product: EVR c...
# 55739  Closed EVR recorded stream data product: EVR c...
# 55740  Closed EVR recorded stream data product: EVR c...
# 55741                                Requesting DMS_STOP
# 55742  Established background state for mode MODE_NOR...
# 55743  Next 5 windows (id, prep time) = (W51711, 5901...
# 55744  Started wait at time 590175574 with delay 3688...
# 55745  EVR recorded stream data product for writing 2...
# 55746  EVR recorded stream data product for writing 1...
# 55747  EVR recorded stream data product for writing 5...
# 55748  EVR recorded stream data product for writing 3...
#
#                                   metadataKeywordList  \
# 0      [(CategorySequenceId),(SequenceId),(TaskName)]
# 1      [(CategorySequenceId),(SequenceId),(TaskName)]
# 2      [(CategorySequenceId),(SequenceId),(TaskName)]
# 3      [(CategorySequenceId),(SequenceId),(TaskName)]
# 4      [(CategorySequenceId),(SequenceId),(TaskName)]
# 5      [(CategorySequenceId),(SequenceId),(TaskName)]
# 6      [(CategorySequenceId),(SequenceId),(TaskName)]
# 7      [(CategorySequenceId),(SequenceId),(TaskName)]
# 8      [(CategorySequenceId),(SequenceId),(TaskName)]
# 9      [(CategorySequenceId),(SequenceId),(TaskName)]
# 10     [(CategorySequenceId),(SequenceId),(TaskName)]
# 11     [(CategorySequenceId),(SequenceId),(TaskName)]
# 12     [(CategorySequenceId),(SequenceId),(TaskName)]
# 13     [(CategorySequenceId),(SequenceId),(TaskName)]
# 14     [(CategorySequenceId),(SequenceId),(TaskName)]
# 15     [(CategorySequenceId),(SequenceId),(TaskName)]
# 16     [(CategorySequenceId),(SequenceId),(TaskName)]
# 17     [(CategorySequenceId),(SequenceId),(TaskName)]
# 18     [(CategorySequenceId),(SequenceId),(TaskName)]
# 19     [(CategorySequenceId),(SequenceId),(TaskName)]
# 20     [(CategorySequenceId),(SequenceId),(TaskName)]
# 21     [(CategorySequenceId),(SequenceId),(TaskName)]
# 22     [(CategorySequenceId),(SequenceId),(TaskName)]
# 23     [(CategorySequenceId),(SequenceId),(TaskName)]
# 24     [(CategorySequenceId),(SequenceId),(TaskName)]
# 25     [(CategorySequenceId),(SequenceId),(TaskName)]
# 26     [(CategorySequenceId),(SequenceId),(TaskName)]
# 27     [(CategorySequenceId),(SequenceId),(TaskName)]
# 28     [(CategorySequenceId),(SequenceId),(TaskName)]
# 29     [(CategorySequenceId),(SequenceId),(TaskName)]
# ...                                               ...
# 55719  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55720  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55721  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55722  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55723  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55724  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55725  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55726  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55727  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55728  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55729  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55730  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55731  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55732  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55733  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55734  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55735  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55736  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55737  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55738  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55739  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55740  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55741  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55742  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55743  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55744  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55745  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55746  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55747  [(CategorySequenceId),(SequenceId),(TaskName)]
# 55748  [(CategorySequenceId),(SequenceId),(TaskName)]
#
#                 metadataValuesList  sessionDssId stringId
# 0            [(0),(RT:1),(fsm???)]             0        B
# 1            [(0),(RT:0),(fsm???)]             0        B
# 2            [(1),(RT:2),(fsm???)]             0        B
# 3            [(2),(RT:3),(fsm???)]             0        B
# 4            [(0),(RT:4),(fsm???)]             0        B
# 5            [(1),(RT:5),(fsm???)]             0        B
# 6            [(2),(RT:6),(fsm???)]             0        B
# 7            [(3),(RT:7),(fsm???)]             0        B
# 8            [(4),(RT:8),(fsm???)]             0        B
# 9            [(5),(RT:9),(fsm???)]             0        B
# 10          [(6),(RT:10),(fsm???)]             0        B
# 11          [(7),(RT:11),(nvmmgr)]             0        B
# 12          [(8),(RT:12),(nvmmgr)]             0        B
# 13          [(9),(RT:13),(nvmmgr)]             0        B
# 14         [(10),(RT:14),(nvmmgr)]             0        B
# 15         [(11),(RT:15),(fsm???)]             0        B
# 16         [(12),(RT:16),(fsm???)]             0        B
# 17         [(13),(RT:17),(fsm???)]             0        B
# 18         [(14),(RT:18),(fsm???)]             0        B
# 19         [(15),(RT:19),(fsm???)]             0        B
# 20         [(16),(RT:20),(fsm???)]             0        B
# 21         [(17),(RT:21),(fsm???)]             0        B
# 22         [(18),(RT:22),(fsm???)]             0        B
# 23         [(19),(RT:23),(fsm???)]             0        B
# 24         [(20),(RT:24),(fsm???)]             0        B
# 25         [(21),(RT:25),(fsm???)]             0        B
# 26         [(22),(RT:26),(fsm???)]             0        B
# 27         [(23),(RT:27),(fsm???)]             0        B
# 28         [(24),(RT:28),(fsm???)]             0        B
# 29         [(25),(RT:29),(fsm???)]             0        B
# ...                            ...           ...      ...
# 55719  [(1205),(RT:1617),(bcmgr8)]             0        B
# 55720  [(1206),(RT:1618),(bcmgr8)]             0        B
# 55721  [(1207),(RT:1619),(bcmgr8)]             0        B
# 55722  [(1208),(RT:1620),(sdst??)]             0        B
# 55723  [(1209),(RT:1621),(bcmgr8)]             0        B
# 55724  [(1210),(RT:1622),(bcmgr8)]             0        B
# 55725  [(1211),(RT:1623),(cbm???)]             0        B
# 55726  [(1212),(RT:1624),(cbm???)]             0        B
# 55727  [(1213),(RT:1625),(bcmgr8)]             0        B
# 55728  [(1214),(RT:1626),(cbm???)]             0        B
# 55729  [(1215),(RT:1627),(bcmgr8)]             0        B
# 55730  [(1216),(RT:1628),(cbm???)]             0        B
# 55731  [(1217),(RT:1629),(bcmgr8)]             0        B
# 55732  [(1218),(RT:1630),(cbm???)]             0        B
# 55733  [(1219),(RT:1631),(cbm???)]             0        B
# 55734  [(1220),(RT:1632),(evr???)]             0        B
# 55735  [(1221),(RT:1633),(evr???)]             0        B
# 55736  [(1222),(RT:1634),(evr???)]             0        B
# 55737  [(1223),(RT:1635),(evr???)]             0        B
# 55738  [(1224),(RT:1636),(evr???)]             0        B
# 55739  [(1225),(RT:1637),(evr???)]             0        B
# 55740  [(1226),(RT:1638),(evr???)]             0        B
# 55741  [(1227),(RT:1639),(cbm???)]             0        B
# 55742    [(37),(RT:1640),(cbm???)]             0        B
# 55743    [(38),(RT:1641),(cbm???)]             0        B
# 55744  [(1228),(RT:1642),(cbm???)]             0        B
# 55745  [(1229),(RT:1643),(evr???)]             0        B
# 55746  [(1230),(RT:1644),(evr???)]             0        B
# 55747  [(1231),(RT:1645),(evr???)]             0        B
# 55748  [(1232),(RT:1646),(evr???)]             0        B
#
# [55749 rows x 19 columns]

# %%
#Making sure right file type

# %%
df_kb_dropped = df_kb.drop(columns=['recordType', 'sessionHost', 'sessionId','fromSse', 'eventId', 'realtime', 'sclk', 'scet',
                    'ert', 'rct', 'metadataKeywordList','metadataValuesList',
                    'sessionDssId','stringId'])

df_kb_dropped
# Out:
#                                      name     module        level  \
# 0         FSM_EVR_FLIGHT_SOFTWARE_VERSION        fsm  ACTIVITY_HI
# 1                      MEM_EVR_BPMM_CRC32        mem  ACTIVITY_LO
# 2                  FSM_EVR_FSW_BUILD_TIME        fsm  ACTIVITY_LO
# 3                FSM_EVR_FSW_ELAPSED_TIME        fsm  ACTIVITY_LO
# 4                   AUT_EVR_BUFFERS_AVAIL        aut   DIAGNOSTIC
# 5                AUT_EVR_AUT_MEMORY_CHECK        aut   DIAGNOSTIC
# 6            AUT_EVR_BUFFERS_AS_REQUESTED        aut   DIAGNOSTIC
# 7                      AUT_EVR_INIT_TYPE3        aut   DIAGNOSTIC
# 8                       AUT_EVR_INIT_DONE        aut   DIAGNOSTIC
# 9                 CRCMGR_EVR_CRCC_PRESENT     crcmgr   DIAGNOSTIC
# 10            NVMCAMMGR_EVR_CRC_5_NOT_SET  nvmcammgr   DIAGNOSTIC
# 11     NVMCAMMGR_EVR_NVMCAM_CARD_DETECTED  nvmcammgr   DIAGNOSTIC
# 12        NVMCAMMGR_EVR_NOR_PWRON_ALREADY  nvmcammgr   DIAGNOSTIC
# 13        NVMCAMMGR_EVR_NVMRAM_START_INIT  nvmcammgr   DIAGNOSTIC
# 14     NVMCAMMGR_EVR_SAVED_NVMRAM_REQUEST  nvmcammgr   DIAGNOSTIC
# 15            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 16            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 17            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 18            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 19             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# 20            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 21             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# 22             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# 23            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 24             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# 25            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 26            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 27            OSAL_EVR_OS_TASK_REGISTERED       osal   DIAGNOSTIC
# 28             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# 29             OSAL_EVR_NO_OS_TASK_EXISTS       osal   DIAGNOSTIC
# ...                                   ...        ...          ...
# 55719             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55720             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55721             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55722             SDST_EVR_STATE_ASSERTED       sdst   DIAGNOSTIC
# 55723             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55724           SDST_EVR_SENDING_CBIT_CMD       sdst   DIAGNOSTIC
# 55725             CBM_EVR_XCONFIG_RECV_5B        cbm   DIAGNOSTIC
# 55726              CBM_EVR_XCONFIG_RECV_6        cbm   DIAGNOSTIC
# 55727             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55728              CBM_EVR_XCONFIG_RECV_7        cbm   DIAGNOSTIC
# 55729             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55730              CBM_EVR_XCONFIG_RECV_8        cbm   DIAGNOSTIC
# 55731             SDST_EVR_SENDING_CMD_ID       sdst   DIAGNOSTIC
# 55732           CBM_EVR_XCONFIG_RECV_DONE        cbm   DIAGNOSTIC
# 55733         CBM_EVR_BKGD_RESTART_EVR_DP        cbm   DIAGNOSTIC
# 55734                EVR_EVR_REC_DP_EMPTY        evr   DIAGNOSTIC
# 55735                EVR_EVR_REC_DP_EMPTY        evr   DIAGNOSTIC
# 55736                EVR_EVR_REC_DP_EMPTY        evr   DIAGNOSTIC
# 55737     EVR_EVR_REC_STREAM_DP_COMPLETED        evr   DIAGNOSTIC
# 55738     EVR_EVR_REC_STREAM_DP_COMPLETED        evr   DIAGNOSTIC
# 55739     EVR_EVR_REC_STREAM_DP_COMPLETED        evr   DIAGNOSTIC
# 55740     EVR_EVR_REC_STREAM_DP_COMPLETED        evr   DIAGNOSTIC
# 55741            CBM_EVR_SENDING_DMS_STOP        cbm   DIAGNOSTIC
# 55742                   CBM_EVR_BKGD_DONE        cbm  ACTIVITY_HI
# 55743           CBM_EVR_NEXT_FIVE_WINDOWS        cbm  ACTIVITY_HI
# 55744                  CBM_EVR_WAIT_BEGIN        cbm   DIAGNOSTIC
# 55745       EVR_EVR_REC_STREAM_DP_CREATED        evr   DIAGNOSTIC
# 55746       EVR_EVR_REC_STREAM_DP_CREATED        evr   DIAGNOSTIC
# 55747       EVR_EVR_REC_STREAM_DP_CREATED        evr   DIAGNOSTIC
# 55748       EVR_EVR_REC_STREAM_DP_CREATED        evr   DIAGNOSTIC
#
#                          lst  \
# 0      SOL-2170M01:32:29.918
# 1      SOL-2170M01:32:29.918
# 2      SOL-2170M01:32:29.918
# 3      SOL-2170M01:32:29.918
# 4      SOL-2170M01:32:29.918
# 5      SOL-2170M01:32:29.918
# 6      SOL-2170M01:32:29.949
# 7      SOL-2170M01:32:29.949
# 8      SOL-2170M01:32:29.949
# 9      SOL-2170M01:32:29.949
# 10     SOL-2170M01:32:29.949
# 11     SOL-2170M01:32:30.390
# 12     SOL-2170M01:32:30.390
# 13     SOL-2170M01:32:30.390
# 14     SOL-2170M01:32:30.390
# 15     SOL-2170M01:32:30.390
# 16     SOL-2170M01:32:30.390
# 17     SOL-2170M01:32:30.390
# 18     SOL-2170M01:32:30.390
# 19     SOL-2170M01:32:30.390
# 20     SOL-2170M01:32:30.390
# 21     SOL-2170M01:32:30.390
# 22     SOL-2170M01:32:30.390
# 23     SOL-2170M01:32:30.390
# 24     SOL-2170M01:32:30.390
# 25     SOL-2170M01:32:30.390
# 26     SOL-2170M01:32:30.390
# 27     SOL-2170M01:32:30.390
# 28     SOL-2170M01:32:30.390
# 29     SOL-2170M01:32:30.390
# ...                      ...
# 55719  SOL-2170M23:57:38.898
# 55720  SOL-2170M23:57:39.871
# 55721  SOL-2170M23:57:40.844
# 55722  SOL-2170M23:57:41.719
# 55723  SOL-2170M23:57:41.817
# 55724  SOL-2170M23:57:41.817
# 55725  SOL-2170M23:57:42.695
# 55726  SOL-2170M23:57:43.669
# 55727  SOL-2170M23:57:43.764
# 55728  SOL-2170M23:57:45.611
# 55729  SOL-2170M23:57:45.710
# 55730  SOL-2170M23:57:47.566
# 55731  SOL-2170M23:57:47.657
# 55732  SOL-2170M23:57:49.509
# 55733  SOL-2170M23:57:49.510
# 55734  SOL-2170M23:57:49.510
# 55735  SOL-2170M23:57:49.510
# 55736  SOL-2170M23:57:49.510
# 55737  SOL-2170M23:57:49.513
# 55738  SOL-2170M23:57:49.513
# 55739  SOL-2170M23:57:49.513
# 55740  SOL-2170M23:57:49.513
# 55741  SOL-2170M23:57:49.514
# 55742  SOL-2170M23:57:49.514
# 55743  SOL-2170M23:57:49.514
# 55744  SOL-2170M23:57:49.514
# 55745  SOL-2170M23:57:49.522
# 55746  SOL-2170M23:57:49.536
# 55747  SOL-2170M23:57:49.550
# 55748  SOL-2170M23:57:49.564
#
#                                                  message
# 0      FSW version 0x0c7365fb, fsw_release_string=R12...
# 1      BPMM addr [0xbf898030], BPMM CRC-32 [0xc71c0011].
# 2      FSW build time: month 8 day 14 year 2014, hour...
# 3      Elapsed time since boot is 20 second(s), with ...
# 4      AUT got memory buffers: mem_rcvd 2097152, reco...
# 5      AUT memory has no data. recoverable FALSE, san...
# 6                         AUT got all requested buffers.
# 7                          AUT init type AUT_INIT_CLEAN.
# 8      AUT done with aut_init: ready for aut_finish_i...
# 9      CRCMGR CRCC Present, board type FLT, serial nu...
# 10       Saw CRC 5 was not set; doing normal NVMRAM init
# 11     Detected NVMCAM card with serial number 193; r...
# 12                   NOR power is already on; continuing
# 13           Starting NVMRAM initialization of section 2
# 14                 Received request for NVMCAM section 3
# 15     OS Task ipcom_syslogd with context id VXW_IPCO...
# 16     OS Task tExcTask with context id VXW_EXC_TASK_...
# 17     OS Task tJobTask with context id VXW_JOB_TASK_...
# 18     OS Task tLogTask with context id VXW_LOG_TASK_...
# 19     Task tNbioLog (VXW_NBIO_LOG_ENTRY) does not ex...
# 20     OS Task tWdbTask with context id VXW_WDB_TASK_...
# 21     Task tAioIoTask0 (VXW_AIO_0_TASK_ENTRY) does n...
# 22     Task tAioIoTask1 (VXW_AIO_1_TASK_ENTRY) does n...
# 23     OS Task tNet0 with context id VXW_NET_TASK_ENT...
# 24     Task tAioWait (VXW_AIO_WAIT_ENTRY) does not ex...
# 25     OS Task tPortmapd with context id VXW_PORTMAPD...
# 26     OS Task tRlogind with context id VXW_RLOGIND_E...
# 27     OS Task tShell0 with context id VXW_SHELL_ENTR...
# 28     Task SimTask (SIM_TASK_ENTRY) does not exist f...
# 29     Task SimIdleTask (SIM_IDLE_TASK_ENTRY) does no...
# ...                                                  ...
# 55719  Write to 1553 subaddress 29, num words = 1, bu...
# 55720  Write to 1553 subaddress 29, num words = 1, bu...
# 55721  Write to 1553 subaddress 29, num words = 1, bu...
# 55722              Default state asserted for SDST ROVER
# 55723  Write to 1553 subaddress 29, num words = 1, bu...
# 55724                 Sending CBIT command to SDST ROVER
# 55725  X-Band Config 5B: Not requesting reset for SDS...
# 55726  X-Band Recv Config 6: Setting SDST uplink rate...
# 55727  Write to 1553 subaddress 29, num words = 1, bu...
# 55728  X-Band Recv Config 7: Setting coherency of SDS...
# 55729  Write to 1553 subaddress 29, num words = 1, bu...
# 55730  X-Band Recv Config 8: Setting receiver bandwid...
# 55731  Write to 1553 subaddress 29, num words = 1, bu...
# 55732         X-Band Recv Config: Finished X-Band config
# 55733  Restarting recorded EVR production after estab...
# 55734  The recorded stream data product of category [...
# 55735  The recorded stream data product of category [...
# 55736  The recorded stream data product of category [...
# 55737  Closed EVR recorded stream data product: EVR c...
# 55738  Closed EVR recorded stream data product: EVR c...
# 55739  Closed EVR recorded stream data product: EVR c...
# 55740  Closed EVR recorded stream data product: EVR c...
# 55741                                Requesting DMS_STOP
# 55742  Established background state for mode MODE_NOR...
# 55743  Next 5 windows (id, prep time) = (W51711, 5901...
# 55744  Started wait at time 590175574 with delay 3688...
# 55745  EVR recorded stream data product for writing 2...
# 55746  EVR recorded stream data product for writing 1...
# 55747  EVR recorded stream data product for writing 5...
# 55748  EVR recorded stream data product for writing 3...
#
# [55749 rows x 5 columns]

# %%
#Write out
# df_kb.to_csv(r'output.csv')

# %%
length = len(df_kb)
result = []
for i in range(0, length):
    if df_kb.loc[i, 'level'] == "ACTIVITY_LO" or df_kb.loc[i, 'level'] == "ACTIVITY_HI":
        df2 = pd.DataFrame(df_kb.iloc[i])
        result.append(df2)

result
# Out:
# [                                                                     0
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                   FSM_EVR_FLIGHT_SOFTWARE_VERSION
#  module                                                             fsm
#  level                                                      ACTIVITY_HI
#  eventId                                                      790726143
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:38.973
#  lst                                              SOL-2170M01:32:29.918
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.257
#  message              FSW version 0x0c7365fb, fsw_release_string=R12...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                               [(0),(RT:1),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                       1
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                                MEM_EVR_BPMM_CRC32
#  module                                                             mem
#  level                                                      ACTIVITY_LO
#  eventId                                                     1280031383
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:38.973
#  lst                                              SOL-2170M01:32:29.918
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.551
#  message              BPMM addr [0xbf898030], BPMM CRC-32 [0xc71c0011].
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                               [(0),(RT:0),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                       2
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                            FSM_EVR_FSW_BUILD_TIME
#  module                                                             fsm
#  level                                                      ACTIVITY_LO
#  eventId                                                      795939399
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:38.973
#  lst                                              SOL-2170M01:32:29.918
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.551
#  message              FSW build time: month 8 day 14 year 2014, hour...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                               [(1),(RT:2),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                       3
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                          FSM_EVR_FSW_ELAPSED_TIME
#  module                                                             fsm
#  level                                                      ACTIVITY_LO
#  eventId                                                      798985376
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:38.973
#  lst                                              SOL-2170M01:32:29.918
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.552
#  message              Elapsed time since boot is 20 second(s), with ...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                               [(2),(RT:3),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                   34
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                  NVDS_EVR_INIT_MOUNT_SUCCEEDED
#  module                                                         nvds
#  level                                                   ACTIVITY_HI
#  eventId                                                  1551555719
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:40.442
#  lst                                           SOL-2170M01:32:31.348
#  ert                                           2018-256T07:47:42.613
#  rct                                           2018-256T07:47:40.257
#  message                        Successfully mounted NPM partition 0
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(1),(RT:35),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   35
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                   NVDS_EVR_NPM_MOUNT_SUCCEEDED
#  module                                                         nvds
#  level                                                   ACTIVITY_LO
#  eventId                                                  1548456267
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:40.442
#  lst                                           SOL-2170M01:32:31.348
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.552
#  message                        NPM partition 0 mounted successfully
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(3),(RT:34),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   38
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                  NVDS_EVR_INIT_MOUNT_SUCCEEDED
#  module                                                         nvds
#  level                                                   ACTIVITY_HI
#  eventId                                                  1551555719
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:41.411
#  lst                                           SOL-2170M01:32:32.291
#  ert                                           2018-256T07:47:42.613
#  rct                                           2018-256T07:47:40.257
#  message                        Successfully mounted NPM partition 1
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(2),(RT:39),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   39
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                   NVDS_EVR_NPM_MOUNT_SUCCEEDED
#  module                                                         nvds
#  level                                                   ACTIVITY_LO
#  eventId                                                  1548456267
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:41.411
#  lst                                           SOL-2170M01:32:32.291
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.552
#  message                        NPM partition 1 mounted successfully
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(4),(RT:38),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                      41
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                              NVFS_EVR_CRC_NOT_SET
#  module                                                            nvfs
#  level                                                      ACTIVITY_HI
#  eventId                                                     1568404491
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:41.614
#  lst                                              SOL-2170M01:32:32.489
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.258
#  message              Saw CRC 49 was not set; NVFS partitions will b...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                              [(3),(RT:43),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                      46
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                     NVFS_EVR_INIT_MOUNT_SUCCEEDED
#  module                                                            nvfs
#  level                                                      ACTIVITY_HI
#  eventId                                                     1568332935
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:48.364
#  lst                                              SOL-2170M01:32:39.058
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.258
#  message              Successfully mounted NVFS partition 2 in 67624...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                              [(4),(RT:47),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                   50
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                RAMFS_EVR_INIT_FORMAT_SUCCEEDED
#  module                                                        ramfs
#  level                                                   ACTIVITY_LO
#  eventId                                                  1796405334
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:48.380
#  lst                                           SOL-2170M01:32:39.074
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.552
#  message                    Successfully formatted RAMFS partition 0
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(5),(RT:50),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   51
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                  RAMFS_EVR_INIT_COLD_SUCCEEDED
#  module                                                        ramfs
#  level                                                   ACTIVITY_LO
#  eventId                                                  1805492795
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:48.380
#  lst                                           SOL-2170M01:32:39.074
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.552
#  message                      Successfully mounted RAMFS partition 0
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(6),(RT:51),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   55
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                RAMFS_EVR_INIT_FORMAT_SUCCEEDED
#  module                                                        ramfs
#  level                                                   ACTIVITY_LO
#  eventId                                                  1796405334
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:48.395
#  lst                                           SOL-2170M01:32:39.088
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.553
#  message                    Successfully formatted RAMFS partition 1
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(7),(RT:55),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                   56
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                  RAMFS_EVR_INIT_COLD_SUCCEEDED
#  module                                                        ramfs
#  level                                                   ACTIVITY_LO
#  eventId                                                  1805492795
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:48.411
#  lst                                           SOL-2170M01:32:39.104
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.553
#  message                      Successfully mounted RAMFS partition 1
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                           [(8),(RT:56),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                      58
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                       TIM_EVR_RECOVERY_TIME_STATE
#  module                                                             tim
#  level                                                      ACTIVITY_LO
#  eventId                                                     2287978210
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:48.427
#  lst                                              SOL-2170M01:32:39.119
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.553
#  message              Spacecraft recovery time state: status=NEW, us...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                              [(9),(RT:63),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                      59
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                        TIM_EVR_MISSION_BOOT_COUNT
#  module                                                             tim
#  level                                                      ACTIVITY_LO
#  eventId                                                     2283341639
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:48.427
#  lst                                              SOL-2170M01:32:39.119
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.553
#  message              There have been 10701 boots since start of mis...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                             [(10),(RT:64),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                      87
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                             DMS_EVR_INIT_COMPLETE
#  module                                                             dms
#  level                                                      ACTIVITY_LO
#  eventId                                                     2562694625
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:49.286
#  lst                                              SOL-2170M01:32:39.955
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.554
#  message              Finished DMS initialization; partitions in use...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                             [(11),(RT:88),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                     154
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                          MCA_EVR_INITIALIZING_MEM
#  module                                                             mca
#  level                                                      ACTIVITY_LO
#  eventId                                                     1187216188
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:52.255
#  lst                                              SOL-2170M01:32:42.845
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.554
#  message              Initializing MCA buffers: shared = 204800 byte...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(12),(RT:155),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                     181
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                   SAM_EVR_FILE_LOAD_MEM_AVAILABLE
#  module                                                             sam
#  level                                                      ACTIVITY_LO
#  eventId                                                     1982260540
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:54.942
#  lst                                              SOL-2170M01:32:45.460
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.554
#  message              SAM load memory stats: addr=0x03f07000, size=8...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(13),(RT:182),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                  186
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                               MHLI_EVR_BITMASK
#  module                                                         mhli
#  level                                                   ACTIVITY_LO
#  eventId                                                  1320617625
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:55.083
#  lst                                           SOL-2170M01:32:45.597
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.554
#  message                            MHLI options_mask is 0x4FFFFFFF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(14),(RT:187),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  188
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                               MRDI_EVR_BITMASK
#  module                                                         mrdi
#  level                                                   ACTIVITY_LO
#  eventId                                                  1404503705
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:55.098
#  lst                                           SOL-2170M01:32:45.612
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.555
#  message                            MRDI options_mask is 0x4FFFFFFF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(15),(RT:190),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  192
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                             MCAM_EVR_L_BITMASK
#  module                                                         mcam
#  level                                                   ACTIVITY_LO
#  eventId                                                  1192403754
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:55.114
#  lst                                           SOL-2170M01:32:45.627
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.555
#  message                          MCAM_L options_mask is 0x4FFF838F.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(16),(RT:195),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  193
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                             MCAM_EVR_R_BITMASK
#  module                                                         mcam
#  level                                                   ACTIVITY_LO
#  eventId                                                  1206862559
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:55.114
#  lst                                           SOL-2170M01:32:45.627
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.555
#  message                          MCAM_R options_mask is 0x4FFF838F.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(17),(RT:196),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                     217
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                         FSM_EVR_LAST_SHUTDOWN_DUR
#  module                                                             fsm
#  level                                                      ACTIVITY_LO
#  eventId                                                      794978302
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:57.942
#  lst                                              SOL-2170M01:32:48.380
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.555
#  message              Previous shutdown of type STANDARD, started at...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(18),(RT:217),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                  218
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                             FSM_EVR_GET_INTENDED_SHUTDOWN_FLAG
#  module                                                          fsm
#  level                                                   ACTIVITY_LO
#  eventId                                                   798266019
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:57.942
#  lst                                           SOL-2170M01:32:48.380
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.555
#  message                             Intended shutdown flag is TRUE.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(19),(RT:218),(fsm???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                     231
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                FSM_EVR_FATAL_DEADEND_STATE_REPORT
#  module                                                             fsm
#  level                                                      ACTIVITY_HI
#  eventId                                                      790535013
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:58.036
#  lst                                              SOL-2170M01:32:48.471
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.259
#  message              FSM fatal reset deadend report: count=0, defau...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                             [(5),(RT:235),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                  238
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                              DWN_EVR_CONFIGURATION_RATE_CHANGE
#  module                                                          dwn
#  level                                                   ACTIVITY_HI
#  eventId                                                   625889041
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:58.052
#  lst                                           SOL-2170M01:32:48.487
#  ert                                           2018-256T07:47:42.613
#  rct                                           2018-256T07:47:40.259
#  message                        New downlink data rate: rate=10 bps.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                          [(6),(RT:240),(dwn???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                     239
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                      DWN_EVR_CONFIGURATION_CHANGE
#  module                                                             dwn
#  level                                                      ACTIVITY_HI
#  eventId                                                      632378734
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:58.052
#  lst                                              SOL-2170M01:32:48.487
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.260
#  message              New downlink configuration: radio=RSDST, lv=TR...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                             [(7),(RT:242),(dwn???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                     254
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                    FSM_EVR_CDH_UPPER256_INIT_DONE
#  module                                                             fsm
#  level                                                      ACTIVITY_LO
#  eventId                                                      798604483
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:58.145
#  lst                                              SOL-2170M01:32:48.577
#  ert                                              2018-256T07:47:43.639
#  rct                                              2018-256T07:47:40.556
#  message              Initialization of upper 256 MB of NVMRAM compl...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(20),(RT:254),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                     263
#  recordType                                                         Evr
#  sessionId                                                        24945
#  sessionHost                                               mslsmsampcs1
#  name                                         FSM_EVR_RESET_INFORMATION
#  module                                                             fsm
#  level                                                      ACTIVITY_HI
#  eventId                                                      790550697
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90093e+08
#  scet                                             2018-256T07:09:59.520
#  lst                                              SOL-2170M01:32:49.916
#  ert                                              2018-256T07:47:42.613
#  rct                                              2018-256T07:47:40.260
#  message              The Reset Source = 0x3, PCI Reset Count = 2, P...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                             [(8),(RT:265),(fsm???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                  270
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                               APXS_EVR_BITMASK
#  module                                                         apxs
#  level                                                   ACTIVITY_LO
#  eventId                                                   129435289
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:59.536
#  lst                                           SOL-2170M01:32:49.931
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.556
#  message                            APXS options_mask is 0x4FFFF7FF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(21),(RT:270),(apxs??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  271
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                                DAN_EVR_BITMASK
#  module                                                          dan
#  level                                                   ACTIVITY_LO
#  eventId                                                   498534041
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:59.536
#  lst                                           SOL-2170M01:32:49.931
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.556
#  message                             DAN options_mask is 0x4FFFF7FF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(22),(RT:271),(dan???)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  272
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                               CCAM_EVR_BITMASK
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   313984665
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:59.536
#  lst                                           SOL-2170M01:32:49.931
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.556
#  message                            CCAM options_mask is 0x4FFFFFFF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(23),(RT:272),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  273
#  recordType                                                      Evr
#  sessionId                                                     24945
#  sessionHost                                            mslsmsampcs1
#  name                                               CHMN_EVR_BITMASK
#  module                                                         chmn
#  level                                                   ACTIVITY_LO
#  eventId                                                   347539097
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90093e+08
#  scet                                          2018-256T07:09:59.536
#  lst                                           SOL-2170M01:32:49.931
#  ert                                           2018-256T07:47:43.639
#  rct                                           2018-256T07:47:40.556
#  message                            CHMN options_mask is 0x4FFFFFFF.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(24),(RT:273),(chmn??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                  274
# ...
#  rct                                              2018-256T14:24:27.464
#  message              Completed establishing the initial operating s...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(66),(RT:652),(pammgr)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                    5169
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                              PWR_EVR_FORCING_CRITICAL_SWITCHES_ON
#  module                                                             pwr
#  level                                                      ACTIVITY_HI
#  eventId                                                     1747383319
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:05.879
#  lst                                              SOL-2170M06:47:17.579
#  ert                                              2018-256T14:24:25.023
#  rct                                              2018-256T14:24:27.272
#  message              Activation complete - forcing this RCE and bot...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(18),(RT:667),(pwr???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                    5175
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                                            MCA_EVR_READ_MCR_STATE
#  module                                                             mca
#  level                                                      ACTIVITY_LO
#  eventId                                                     1180826517
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:05.909
#  lst                                              SOL-2170M06:47:17.608
#  ert                                              2018-256T14:24:26.335
#  rct                                              2018-256T14:24:27.464
#  message              Using ARM drivers: PRIME PRIME PRIME PRIME PRIME.
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(67),(RT:673),(mca???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                    5176
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                                           MCA_EVR_SETTING_FP_MODE
#  module                                                             mca
#  level                                                      ACTIVITY_LO
#  eventId                                                     1182574463
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:05.910
#  lst                                              SOL-2170M06:47:17.609
#  ert                                              2018-256T14:24:26.335
#  rct                                              2018-256T14:24:27.464
#  message              RMCA fault protection mode has been set to RMC...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(68),(RT:674),(mca???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                    5177
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                                           MCA_EVR_SETTING_FP_MODE
#  module                                                             mca
#  level                                                      ACTIVITY_LO
#  eventId                                                     1182574463
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:05.910
#  lst                                              SOL-2170M06:47:17.609
#  ert                                              2018-256T14:24:26.335
#  rct                                              2018-256T14:24:27.465
#  message              DMCA fault protection mode has been set to DMC...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(69),(RT:675),(mca???)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                 5193
#  recordType                                                      Evr
#  sessionId                                                     24942
#  sessionHost                                            mslsmsampcs1
#  name                                   CCAM_EVR_CAMERA_MODEL_UPDATE
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   303089183
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90112e+08
#  scet                                          2018-256T12:33:06.073
#  lst                                           SOL-2170M06:47:17.768
#  ert                                           2018-256T14:24:26.335
#  rct                                           2018-256T14:24:27.465
#  message                    ChemCam Camera model 0 is being updated.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(70),(RT:691),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                 5194
#  recordType                                                      Evr
#  sessionId                                                     24942
#  sessionHost                                            mslsmsampcs1
#  name                                   CCAM_EVR_CAMERA_MODEL_UPDATE
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   303089183
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90112e+08
#  scet                                          2018-256T12:33:06.074
#  lst                                           SOL-2170M06:47:17.769
#  ert                                           2018-256T14:24:26.335
#  rct                                           2018-256T14:24:27.465
#  message                    ChemCam Camera model 1 is being updated.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(71),(RT:692),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                 5195
#  recordType                                                      Evr
#  sessionId                                                     24942
#  sessionHost                                            mslsmsampcs1
#  name                                   CCAM_EVR_CAMERA_MODEL_UPDATE
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   303089183
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90112e+08
#  scet                                          2018-256T12:33:06.074
#  lst                                           SOL-2170M06:47:17.769
#  ert                                           2018-256T14:24:26.335
#  rct                                           2018-256T14:24:27.465
#  message                    ChemCam Camera model 2 is being updated.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(72),(RT:693),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                 5196
#  recordType                                                      Evr
#  sessionId                                                     24942
#  sessionHost                                            mslsmsampcs1
#  name                                   CCAM_EVR_CAMERA_MODEL_UPDATE
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   303089183
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90112e+08
#  scet                                          2018-256T12:33:06.074
#  lst                                           SOL-2170M06:47:17.769
#  ert                                           2018-256T14:24:26.335
#  rct                                           2018-256T14:24:27.465
#  message                    ChemCam Camera model 3 is being updated.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(73),(RT:694),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                 5197
#  recordType                                                      Evr
#  sessionId                                                     24942
#  sessionHost                                            mslsmsampcs1
#  name                                   CCAM_EVR_CAMERA_MODEL_UPDATE
#  module                                                         ccam
#  level                                                   ACTIVITY_LO
#  eventId                                                   303089183
#  fromSse                                                       False
#  realtime                                                      False
#  sclk                                                    5.90112e+08
#  scet                                          2018-256T12:33:06.074
#  lst                                           SOL-2170M06:47:17.769
#  ert                                           2018-256T14:24:26.335
#  rct                                           2018-256T14:24:27.466
#  message                    ChemCam Camera model 4 is being updated.
#  metadataKeywordList  [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                         [(74),(RT:695),(ccam??)]
#  sessionDssId                                                      0
#  stringId                                                          B,
#                                                                    5198
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                                CCAM_EVR_SET_RVR_RMI_FRAME_SUCCESS
#  module                                                            ccam
#  level                                                      ACTIVITY_LO
#  eventId                                                      305915722
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:06.075
#  lst                                              SOL-2170M06:47:17.770
#  ert                                              2018-256T14:24:26.335
#  rct                                              2018-256T14:24:27.466
#  message              The ChemCam RMI rover frame is set for camera ...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(75),(RT:696),(ccam??)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#                                                                    5199
#  recordType                                                         Evr
#  sessionId                                                        24942
#  sessionHost                                               mslsmsampcs1
#  name                               CCAM_EVR_SET_RVR_LIBS_FRAME_SUCCESS
#  module                                                            ccam
#  level                                                      ACTIVITY_LO
#  eventId                                                      304390726
#  fromSse                                                          False
#  realtime                                                         False
#  sclk                                                       5.90112e+08
#  scet                                             2018-256T12:33:06.076
#  lst                                              SOL-2170M06:47:17.771
#  ert                                              2018-256T14:24:26.335
#  rct                                              2018-256T14:24:27.466
#  message              The ChemCam LIBS rover frame is set for camera...
#  metadataKeywordList     [(CategorySequenceId),(SequenceId),(TaskName)]
#  metadataValuesList                            [(76),(RT:697),(ccam??)]
#  sessionDssId                                                         0
#  stringId                                                             B,
#  ...]

# %%
for uniqueId in data.keys():
    amountMarginUsed = round((data[uniqueId]['planMarginDur'] - data[uniqueId]['actMarginDur'])/60,3)
    print(uniqueId, amountMarginUsed)
# Out:
# sol2170_sub_00170 28.381
# sol2170_sub_01170 -1.446
# sol2171_sub_00171 -7.907
# sol2209_sub_00209 -2.901
# sol2209_sub_01209 -1.894
# sol2209_sub_02209 -1.66
# sol2209_sub_03209 -1.893
# sol2209_sub_04209 -2.012
# sol2209_sub_04210 -1.166
# sol2209_sub_05209 -2.01
# sol2209_sub_05210 -1.636
# sol2209_sub_06209 -1.33
# sol2209_sub_06210 -1.649
# sol2209_sub_07209 -1.426
# sol2209_sub_07210 -1.653
# sol2209_sub_08209 -1.772
# sol2209_sub_09209 -1.198
# sol2209_sub_10209 -1.176
# sol2209_sub_11209 -1.118
# sol2209_sub_12209 -0.931
